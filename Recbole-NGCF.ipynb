# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/Shareddrives/SI650_Final_Project/RecBole
# !pip install -e .
# Out:
# /content/drive/Shareddrives/SI650_Final_Project/RecBole
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/drive/Shareddrives/SI650_Final_Project/RecBole
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.8/dist-packages (from recbole==1.1.1) (1.13.0+cu116)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.8/dist-packages (from recbole==1.1.1) (1.21.6)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from recbole==1.1.1) (1.7.3)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.8/dist-packages (from recbole==1.1.1) (1.3.5)
# Requirement already satisfied: tqdm>=4.48.2 in /usr/local/lib/python3.8/dist-packages (from recbole==1.1.1) (4.64.1)
# Collecting colorlog==4.7.2
#   Downloading colorlog-4.7.2-py2.py3-none-any.whl (10 kB)
# Collecting colorama==0.4.4
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: scikit_learn>=0.23.2 in /usr/local/lib/python3.8/dist-packages (from recbole==1.1.1) (1.0.2)
# Requirement already satisfied: pyyaml>=5.1.0 in /usr/local/lib/python3.8/dist-packages (from recbole==1.1.1) (6.0)
# Requirement already satisfied: tensorboard>=2.5.0 in /usr/local/lib/python3.8/dist-packages (from recbole==1.1.1) (2.9.1)
# Collecting thop>=0.1.1.post2207130030
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: tabulate>=0.8.10 in /usr/local/lib/python3.8/dist-packages (from recbole==1.1.1) (0.8.10)
# Requirement already satisfied: plotly>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from recbole==1.1.1) (5.5.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.5->recbole==1.1.1) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.5->recbole==1.1.1) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from plotly>=4.0.0->recbole==1.1.1) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from plotly>=4.0.0->recbole==1.1.1) (8.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit_learn>=0.23.2->recbole==1.1.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit_learn>=0.23.2->recbole==1.1.1) (3.1.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (2.23.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (2.15.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (3.4.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (3.19.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (0.38.4)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (1.51.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (1.3.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.5.0->recbole==1.1.1) (57.4.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.5.0->recbole==1.1.1) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.5.0->recbole==1.1.1) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.5.0->recbole==1.1.1) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.5.0->recbole==1.1.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard>=2.5.0->recbole==1.1.1) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.5.0->recbole==1.1.1) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.5.0->recbole==1.1.1) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.5.0->recbole==1.1.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.5.0->recbole==1.1.1) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.5.0->recbole==1.1.1) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.5.0->recbole==1.1.1) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.5.0->recbole==1.1.1) (3.2.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.10.0->recbole==1.1.1) (4.4.0)
# Installing collected packages: thop, colorlog, colorama, recbole
#   Running setup.py develop for recbole
# Successfully installed colorama-0.4.4 colorlog-4.7.2 recbole-1.1.1 thop-0.1.1.post2209072238

# %%
# !pip install ray
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ray
#   Downloading ray-2.2.0-cp38-cp38-manylinux2014_x86_64.whl (57.4 MB)
#      |████████████████████████████████| 57.4 MB 1.6 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from ray) (2.23.0)
# Collecting virtualenv>=20.0.24
#   Downloading virtualenv-20.17.1-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 70.0 MB/s
# Requirement already satisfied: attrs in /usr/local/lib/python3.8/dist-packages (from ray) (22.1.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.8/dist-packages (from ray) (1.21.6)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ray) (1.0.4)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.8/dist-packages (from ray) (4.3.3)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.8/dist-packages (from ray) (1.3.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from ray) (6.0)
# Requirement already satisfied: grpcio>=1.32.0 in /usr/local/lib/python3.8/dist-packages (from ray) (1.51.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.8/dist-packages (from ray) (7.1.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.8/dist-packages (from ray) (3.19.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from ray) (3.8.0)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.8/dist-packages (from ray) (1.3.3)
# Requirement already satisfied: platformdirs<3,>=2.4 in /usr/local/lib/python3.8/dist-packages (from virtualenv>=20.0.24->ray) (2.5.4)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      |████████████████████████████████| 468 kB 58.9 MB/s
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray) (0.19.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray) (5.10.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema->ray) (3.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (1.24.3)
# Installing collected packages: distlib, virtualenv, ray
# Successfully installed distlib-0.3.6 ray-2.2.0 virtualenv-20.17.1

# %%
DATA_DIR = "/content/drive/Shareddrives/SI650_Final_Project/RecBole/dataset/ZhihuRec-1M"
DIR = "/content/drive/Shareddrives/SI650_Final_Project/RecBole"
SOURCE_DIR = "/content/drive/Shareddrives/SI650_Final_Project/ZhihuRec-1M"

# %%
# %cd /content/drive/Shareddrives/SI650_Final_Project/Recbole-Debias
# Out:
# /content/drive/Shareddrives/SI650_Final_Project/Recbole-Debias

# %%
# NGCF
! python ../bole/run.py --model=NGCF
# Out:
# 16 Dec 01:37    INFO  ['../bole/run.py', '--model=NGCF']
# 16 Dec 01:37    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = /content/drive/Shareddrives/SI650_Final_Project/RecBole/dataset/ZhihuRec-1M
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 300
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 2048
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator = ,
# seq_separator =
# USER_ID_FIELD = userID
# ITEM_ID_FIELD = answerID
# RATING_FIELD = is_clicked
# TIME_FIELD = imp_ts
# seq_len = None
# LABEL_FIELD = is_clicked
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['userID', 'answerID', 'imp_ts', 'is_clicked'], 'item': ['answerID', 'is_anonymous', 'is_hi_val', 'is_editor_recom', 'has_pic', 'has_vid', 'n_thanks', 'n_likes', 'n_comments', 'n_collections', 'n_dislikes', 'n_reports', 'n_helpless']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'val', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# hidden_size_list = [64, 64, 64]
# node_dropout = 0.0
# message_dropout = 0.1
# reg_weight = 1e-05
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cuda
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 16 Dec 01:37    INFO  ZhihuRec-1M
# The number of users: 7975
# Average actions of users: 125.40381239026837
# The number of items: 81564
# Average actions of items: 12.260093424714638
# The number of inters: 999970
# The sparsity of the dataset: 99.84627030580367%
# Remain Fields: ['userID', 'answerID', 'is_clicked', 'imp_ts', 'is_anonymous', 'is_hi_val', 'is_editor_recom', 'has_pic', 'has_vid', 'n_thanks', 'n_likes', 'n_comments', 'n_collections', 'n_dislikes', 'n_reports', 'n_helpless']
# 16 Dec 01:37    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 16 Dec 01:37    INFO  [Evaluation]: eval_batch_size = [2048] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}]
# 16 Dec 01:38    INFO  NGCF(
#   (sparse_dropout): SparseDropout()
#   (user_embedding): Embedding(7975, 64)
#   (item_embedding): Embedding(81564, 64)
#   (GNNlayers): ModuleList(
#     (0): BiGNNLayer(
#       (linear): Linear(in_features=64, out_features=64, bias=True)
#       (interActTransform): Linear(in_features=64, out_features=64, bias=True)
#     )
#     (1): BiGNNLayer(
#       (linear): Linear(in_features=64, out_features=64, bias=True)
#       (interActTransform): Linear(in_features=64, out_features=64, bias=True)
#     )
#     (2): BiGNNLayer(
#       (linear): Linear(in_features=64, out_features=64, bias=True)
#       (interActTransform): Linear(in_features=64, out_features=64, bias=True)
#     )
#   )
#   (mf_loss): BPRLoss()
#   (reg_loss): EmbLoss()
# )
# Trainable parameters: 5755456
# 16 Dec 01:38    INFO  FLOPs: 2200510464.0
# Train     0: 100%|███████████████████████| 905/905 [02:00<00:00,  7.49it/s, GPU RAM: 0.89 G/14.76 G]
# 16 Dec 01:40    INFO  epoch 0 training [time: 120.75s, train loss: 183.8735]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:12<00:00, 652.93it/s, GPU RAM: 0.89 G/14.76 G]
# 16 Dec 01:40    INFO  epoch 0 evaluating [time: 12.29s, valid_score: 0.007100]
# 16 Dec 01:40    INFO  valid result:
# recall@10 : 0.0057    mrr@10 : 0.0071    ndcg@10 : 0.0043    hit@10 : 0.0242    precision@10 : 0.0026    map@10 : 0.002
# 16 Dec 01:40    INFO  Saving current: saved/NGCF-Dec-16-2022_01-38-12.pth
# Train     1: 100%|███████████████████████| 905/905 [01:59<00:00,  7.55it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 01:42    INFO  epoch 1 training [time: 119.80s, train loss: 145.4607]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:11<00:00, 671.08it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 01:42    INFO  epoch 1 evaluating [time: 11.95s, valid_score: 0.010400]
# 16 Dec 01:42    INFO  valid result:
# recall@10 : 0.007    mrr@10 : 0.0104    ndcg@10 : 0.0055    hit@10 : 0.0324    precision@10 : 0.0033    map@10 : 0.0025
# 16 Dec 01:42    INFO  Saving current: saved/NGCF-Dec-16-2022_01-38-12.pth
# Train     2: 100%|███████████████████████| 905/905 [01:59<00:00,  7.55it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 01:44    INFO  epoch 2 training [time: 119.86s, train loss: 132.8255]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:11<00:00, 668.03it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 01:44    INFO  epoch 2 evaluating [time: 12.00s, valid_score: 0.012100]
# 16 Dec 01:44    INFO  valid result:
# recall@10 : 0.0109    mrr@10 : 0.0121    ndcg@10 : 0.0075    hit@10 : 0.0404    precision@10 : 0.0042    map@10 : 0.0035
# 16 Dec 01:44    INFO  Saving current: saved/NGCF-Dec-16-2022_01-38-12.pth
# Train     3: 100%|███████████████████████| 905/905 [01:59<00:00,  7.55it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 01:46    INFO  epoch 3 training [time: 119.82s, train loss: 124.7850]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:12<00:00, 652.06it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 01:47    INFO  epoch 3 evaluating [time: 12.30s, valid_score: 0.016700]
# 16 Dec 01:47    INFO  valid result:
# recall@10 : 0.0149    mrr@10 : 0.0167    ndcg@10 : 0.0106    hit@10 : 0.05    precision@10 : 0.0053    map@10 : 0.0054
# 16 Dec 01:47    INFO  Saving current: saved/NGCF-Dec-16-2022_01-38-12.pth
# Train     4: 100%|███████████████████████| 905/905 [01:59<00:00,  7.55it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 01:49    INFO  epoch 4 training [time: 119.81s, train loss: 117.5530]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:12<00:00, 664.09it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 01:49    INFO  epoch 4 evaluating [time: 12.07s, valid_score: 0.020600]
# 16 Dec 01:49    INFO  valid result:
# recall@10 : 0.0187    mrr@10 : 0.0206    ndcg@10 : 0.0131    hit@10 : 0.062    precision@10 : 0.0066    map@10 : 0.0067
# 16 Dec 01:49    INFO  Saving current: saved/NGCF-Dec-16-2022_01-38-12.pth
# Train     5: 100%|███████████████████████| 905/905 [01:59<00:00,  7.56it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 01:51    INFO  epoch 5 training [time: 119.78s, train loss: 109.2006]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:11<00:00, 665.85it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 01:51    INFO  epoch 5 evaluating [time: 12.04s, valid_score: 0.020600]
# 16 Dec 01:51    INFO  valid result:
# recall@10 : 0.0185    mrr@10 : 0.0206    ndcg@10 : 0.0127    hit@10 : 0.0609    precision@10 : 0.0065    map@10 : 0.0062
# 16 Dec 01:51    INFO  Saving current: saved/NGCF-Dec-16-2022_01-38-12.pth
# Train     6: 100%|███████████████████████| 905/905 [01:59<00:00,  7.56it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 01:53    INFO  epoch 6 training [time: 119.79s, train loss: 100.3446]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:11<00:00, 673.57it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 01:53    INFO  epoch 6 evaluating [time: 11.90s, valid_score: 0.022500]
# 16 Dec 01:53    INFO  valid result:
# recall@10 : 0.02    mrr@10 : 0.0225    ndcg@10 : 0.0141    hit@10 : 0.0645    precision@10 : 0.0069    map@10 : 0.0072
# 16 Dec 01:53    INFO  Saving current: saved/NGCF-Dec-16-2022_01-38-12.pth
# Train     7: 100%|███████████████████████| 905/905 [01:59<00:00,  7.55it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 01:55    INFO  epoch 7 training [time: 119.80s, train loss: 91.2269]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:12<00:00, 658.15it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 01
/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:10    INFO  epoch 41 evaluating [time: 12.34s, valid_score: 0.027500]
# 16 Dec 03:10    INFO  valid result:
# recall@10 : 0.0252    mrr@10 : 0.0275    ndcg@10 : 0.0177    hit@10 : 0.0796    precision@10 : 0.0088    map@10 : 0.0091
# 16 Dec 03:10    INFO  Saving current: saved/NGCF-Dec-16-2022_01-38-12.pth
# Train    42: 100%|███████████████████████| 905/905 [01:59<00:00,  7.55it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:12    INFO  epoch 42 training [time: 119.82s, train loss: 20.1327]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:12<00:00, 659.01it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:12    INFO  epoch 42 evaluating [time: 12.16s, valid_score: 0.026500]
# 16 Dec 03:12    INFO  valid result:
# recall@10 : 0.0235    mrr@10 : 0.0265    ndcg@10 : 0.0167    hit@10 : 0.0766    precision@10 : 0.0085    map@10 : 0.0085
# Train    43: 100%|███████████████████████| 905/905 [01:59<00:00,  7.55it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:14    INFO  epoch 43 training [time: 119.86s, train loss: 19.7414]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:12<00:00, 661.44it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:15    INFO  epoch 43 evaluating [time: 12.12s, valid_score: 0.026200]
# 16 Dec 03:15    INFO  valid result:
# recall@10 : 0.0234    mrr@10 : 0.0262    ndcg@10 : 0.0167    hit@10 : 0.0752    precision@10 : 0.0084    map@10 : 0.0087
# Train    44: 100%|███████████████████████| 905/905 [01:59<00:00,  7.55it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:17    INFO  epoch 44 training [time: 119.95s, train loss: 19.4245]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:12<00:00, 660.34it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:17    INFO  epoch 44 evaluating [time: 12.14s, valid_score: 0.025900]
# 16 Dec 03:17    INFO  valid result:
# recall@10 : 0.0226    mrr@10 : 0.0259    ndcg@10 : 0.0162    hit@10 : 0.0746    precision@10 : 0.0083    map@10 : 0.0083
# Train    45: 100%|███████████████████████| 905/905 [01:59<00:00,  7.55it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:19    INFO  epoch 45 training [time: 119.80s, train loss: 19.2937]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:12<00:00, 660.24it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:19    INFO  epoch 45 evaluating [time: 12.14s, valid_score: 0.025800]
# 16 Dec 03:19    INFO  valid result:
# recall@10 : 0.0237    mrr@10 : 0.0258    ndcg@10 : 0.0165    hit@10 : 0.0775    precision@10 : 0.0086    map@10 : 0.0083
# Train    46: 100%|███████████████████████| 905/905 [01:59<00:00,  7.55it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:21    INFO  epoch 46 training [time: 119.85s, train loss: 18.6934]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:12<00:00, 660.43it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:21    INFO  epoch 46 evaluating [time: 12.14s, valid_score: 0.025500]
# 16 Dec 03:21    INFO  valid result:
# recall@10 : 0.0237    mrr@10 : 0.0255    ndcg@10 : 0.0166    hit@10 : 0.0757    precision@10 : 0.0083    map@10 : 0.0086
# Train    47: 100%|███████████████████████| 905/905 [01:59<00:00,  7.56it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:23    INFO  epoch 47 training [time: 119.78s, train loss: 18.5130]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:12<00:00, 661.17it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:23    INFO  epoch 47 evaluating [time: 12.12s, valid_score: 0.024500]
# 16 Dec 03:23    INFO  valid result:
# recall@10 : 0.0246    mrr@10 : 0.0245    ndcg@10 : 0.0165    hit@10 : 0.0771    precision@10 : 0.0084    map@10 : 0.0083
# Train    48: 100%|███████████████████████| 905/905 [01:59<00:00,  7.56it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:25    INFO  epoch 48 training [time: 119.77s, train loss: 18.1530]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:12<00:00, 663.85it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:26    INFO  epoch 48 evaluating [time: 12.07s, valid_score: 0.024300]
# 16 Dec 03:26    INFO  valid result:
# recall@10 : 0.0235    mrr@10 : 0.0243    ndcg@10 : 0.0161    hit@10 : 0.0761    precision@10 : 0.0084    map@10 : 0.0081
# Train    49: 100%|███████████████████████| 905/905 [01:59<00:00,  7.56it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:28    INFO  epoch 49 training [time: 119.72s, train loss: 18.0417]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:11<00:00, 668.31it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:28    INFO  epoch 49 evaluating [time: 11.99s, valid_score: 0.026400]
# 16 Dec 03:28    INFO  valid result:
# recall@10 : 0.0249    mrr@10 : 0.0264    ndcg@10 : 0.0172    hit@10 : 0.0796    precision@10 : 0.0088    map@10 : 0.0087
# Train    50: 100%|███████████████████████| 905/905 [01:59<00:00,  7.56it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:30    INFO  epoch 50 training [time: 119.77s, train loss: 17.9354]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:11<00:00, 666.23it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:30    INFO  epoch 50 evaluating [time: 12.03s, valid_score: 0.026600]
# 16 Dec 03:30    INFO  valid result:
# recall@10 : 0.0245    mrr@10 : 0.0266    ndcg@10 : 0.0169    hit@10 : 0.0783    precision@10 : 0.0086    map@10 : 0.0085
# Train    51: 100%|███████████████████████| 905/905 [01:59<00:00,  7.56it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:32    INFO  epoch 51 training [time: 119.77s, train loss: 17.8762]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:11<00:00, 668.67it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:32    INFO  epoch 51 evaluating [time: 11.99s, valid_score: 0.025600]
# 16 Dec 03:32    INFO  valid result:
# recall@10 : 0.0236    mrr@10 : 0.0256    ndcg@10 : 0.0164    hit@10 : 0.0773    precision@10 : 0.0085    map@10 : 0.0082
# Train    52: 100%|███████████████████████| 905/905 [01:59<00:00,  7.55it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:34    INFO  epoch 52 training [time: 119.81s, train loss: 17.7744]
# Evaluate   : 100%|████████████████████| 7974/7974 [00:11<00:00, 668.12it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:34    INFO  epoch 52 evaluating [time: 12.00s, valid_score: 0.024800]
# 16 Dec 03:34    INFO  valid result:
# recall@10 : 0.0238    mrr@10 : 0.0248    ndcg@10 : 0.0163    hit@10 : 0.0773    precision@10 : 0.0085    map@10 : 0.0081
# 16 Dec 03:34    INFO  Finished training, best eval result in epoch 41
# 16 Dec 03:34    INFO  Loading model structure and parameters from saved/NGCF-Dec-16-2022_01-38-12.pth
# Evaluate   : 100%|████████████████████| 7974/7974 [00:12<00:00, 662.73it/s, GPU RAM: 0.90 G/14.76 G]
# 16 Dec 03:35    INFO  best valid : OrderedDict([('recall@10', 0.0252), ('mrr@10', 0.0275), ('ndcg@10', 0.0177), ('hit@10', 0.0796), ('precision@10', 0.0088), ('map@10', 0.0091)])
# 16 Dec 03:35    INFO  test result: OrderedDict([('recall@10', 0.0232), ('mrr@10', 0.0253), ('ndcg@10', 0.0165), ('hit@10', 0.0734), ('precision@10', 0.0083), ('map@10', 0.0087)])

# %%
# pop
! python ../bole/run.py --model=Pop
# Out:
# 02 Dec 01:22    INFO  ['../bole/run.py']
# 02 Dec 01:22    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = /content/drive/Shareddrives/SI650_Final_Project/RecBole/dataset/ZhihuRec-1M
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 300
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator = ,
# seq_separator =
# USER_ID_FIELD = userID
# ITEM_ID_FIELD = answerID
# RATING_FIELD = is_clicked
# TIME_FIELD = imp_ts
# seq_len = None
# LABEL_FIELD = is_clicked
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['userID', 'answerID', 'imp_ts', 'is_clicked']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'val', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.TRADITIONAL
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 02 Dec 01:22    INFO  ZhihuRec-1M
# The number of users: 7975
# Average actions of users: 125.40381239026837
# The number of items: 81564
# Average actions of items: 12.260093424714638
# The number of inters: 999970
# The sparsity of the dataset: 99.84627030580367%
# Remain Fields: ['userID', 'answerID', 'is_clicked', 'imp_ts']
# 02 Dec 01:22    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 02 Dec 01:22    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}]
# 02 Dec 01:22    INFO  Pop()
# Trainable parameters: 1
# 02 Dec 01:22    INFO  FLOPs: 1
# Train     0: 100%|███████████████████████████████████████████████| 905/905 [00:03<00:00, 241.05it/s]
# 02 Dec 01:22    INFO  epoch 0 training [time: 3.76s, train loss: 0.0000]
# Evaluate   : 100%|█████████████████████████████████████████████| 7974/7974 [00:15<00:00, 502.38it/s]
# 02 Dec 01:23    INFO  epoch 0 evaluating [time: 15.98s, valid_score: 0.010800]
# 02 Dec 01:23    INFO  valid result:
# recall@10 : 0.0108    mrr@10 : 0.0108    ndcg@10 : 0.0072    hit@10 : 0.0337    precision@10 : 0.0036    map@10 : 0.0037
# 02 Dec 01:23    INFO  Saving current: saved/Pop-Dec-02-2022_01-22-42.pth
# 02 Dec 01:23    INFO  Loading model structure and parameters from saved/Pop-Dec-02-2022_01-22-42.pth
# Evaluate   : 100%|█████████████████████████████████████████████| 7974/7974 [00:15<00:00, 516.70it/s]
# 02 Dec 01:23    INFO  best valid : OrderedDict([('recall@10', 0.0108), ('mrr@10', 0.0108), ('ndcg@10', 0.0072), ('hit@10', 0.0337), ('precision@10', 0.0036), ('map@10', 0.0037)])
# 02 Dec 01:23    INFO  test result: OrderedDict([('recall@10', 0.0125), ('mrr@10', 0.0112), ('ndcg@10', 0.008), ('hit@10', 0.0337), ('precision@10', 0.0036), ('map@10', 0.0041)])

# %%
# MF
! python ../bole/run.py --model=MF
# Out:
# 02 Dec 01:25    INFO  ['../bole/run.py']
# 02 Dec 01:25    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = /content/drive/Shareddrives/SI650_Final_Project/RecBole/dataset/ZhihuRec-1M
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 300
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator = ,
# seq_separator =
# USER_ID_FIELD = userID
# ITEM_ID_FIELD = answerID
# RATING_FIELD = is_clicked
# TIME_FIELD = imp_ts
# seq_len = None
# LABEL_FIELD = is_clicked
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['userID', 'answerID', 'imp_ts', 'is_clicked']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'val', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# user_embedding_size = 64
# item_embedding_size = 64
# user_hidden_size_list = [64, 64]
# item_hidden_size_list = [64, 64]
# embedding_size = 10
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 02 Dec 01:25    INFO  ZhihuRec-1M
# The number of users: 7975
# Average actions of users: 125.40381239026837
# The number of items: 81564
# Average actions of items: 12.260093424714638
# The number of inters: 999970
# The sparsity of the dataset: 99.84627030580367%
# Remain Fields: ['userID', 'answerID', 'is_clicked', 'imp_ts']
# 02 Dec 01:25    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 02 Dec 01:25    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}]
# 02 Dec 01:25    INFO  MF(
#   (user_embedding): Embedding(7975, 10)
#   (item_embedding): Embedding(81564, 10)
#   (loss): MSELoss()
#   (bce_loss): BCEWithLogitsLoss()
#   (sigmoid): Sigmoid()
# )
# Trainable parameters: 895390
# 02 Dec 01:25    INFO  FLOPs: 20.0
# Train     0: 100%|████████████████████████████████████████████████| 905/905 [00:13<00:00, 69.41it/s]
# 02 Dec 01:25    INFO  epoch 0 training [time: 13.04s, train loss: 320.9653]
# Evaluate   : 100%|█████████████████████████████████████████████| 7974/7974 [00:16<00:00, 485.37it/s]
# 02 Dec 01:25    INFO  epoch 0 evaluating [time: 16.51s, valid_score: 0.011400]
# 02 Dec 01:25    INFO  valid result:
# recall@10 : 0.0107    mrr@10 : 0.0114    ndcg@10 : 0.0072    hit@10 : 0.0352    precision@10 : 0.0036    map@10 : 0.0035
# 02 Dec 01:25    INFO  Saving current: saved/MF-Dec-02-2022_01-25-15.pth
# Train     1: 100%|████████████████████████████████████████████████| 905/905 [00:11<00:00, 81.42it/s]
# 02 Dec 01:25    INFO  epoch 1 training [time: 11.12s, train loss: 111.6411]
# Evaluate   : 100%|█████████████████████████████████████████████| 7974/7974 [00:15<00:00, 514.46it/s]
# 02 Dec 01:26    INFO  epoch 1 evaluating [time: 15.57s, valid_score: 0.005600]
# 02 Dec 01:26    INFO  valid result:
# recall@10 : 0.0077    mrr@10 : 0.0056    ndcg@10 : 0.0044    hit@10 : 0.0219    precision@10 : 0.0022    map@10 : 0.0021
# Train     2: 100%|████████████████████████████████████████████████| 905/905 [00:11<00:00, 81.83it/s]
# 02 Dec 01:26    INFO  epoch 2 training [time: 11.06s, train loss: 99.3033]
# Evaluate   : 100%|█████████████████████████████████████████████| 7974/7974 [00:15<00:00, 519.97it/s]
# 02 Dec 01:26    INFO  epoch 2 evaluating [time: 15.41s, valid_score: 0.008200]
# 02 Dec 01:26    INFO  valid result:
# recall@10 : 0.0081    mrr@10 : 0.0082    ndcg@10 : 0.0053    hit@10 : 0.0268    precision@10 : 0.0028    map@10 : 0.0026
# Train     3: 100%|████████████████████████████████████████████████| 905/905 [00:11<00:00, 80.94it/s]
# 02 Dec 01:26    INFO  epoch 3 training [time: 11.18s, train loss: 94.4148]
# Evaluate   : 100%|█████████████████████████████████████████████| 7974/7974 [00:15<00:00, 514.68it/s]
# 02 Dec 01:27    INFO  epoch 3 evaluating [time: 15.56s, valid_score: 0.007600]
# 02 Dec 01:27    INFO  valid result:
# recall@10 : 0.0082    mrr@10 : 0.0076    ndcg@10 : 0.0052    hit@10 : 0.0282    precision@10 : 0.0029    map@10 : 0.0023
# Train     4: 100%|████████████████████████████████████████████████| 905/905 [00:11<00:00, 81.25it/s]
# 02 Dec 01:27    INFO  epoch 4 training [time: 11.14s, train loss: 90.6585]
# Evaluate   : 100%|█████████████████████████████████████████████| 7974/7974 [00:15<00:00, 510.03it/s]
# 02 Dec 01:27    INFO  epoch 4 evaluating [time: 15.71s, valid_score: 0.008500]
# 02 Dec 01:27    INFO  valid result:
# recall@10 : 0.0084    mrr@10 : 0.0085    ndcg@10 : 0.0055    hit@10 : 0.0295    precision@10 : 0.0031    map@10 : 0.0025
# Train     5: 100%|████████████████████████████████████████████████| 905/905 [00:11<00:00,
# Evaluate   : 100%|█████████████████████████████████████████████| 7974/7974 [00:16<00:00, 478.62it/s]
# 02 Dec 01:31    INFO  best valid : OrderedDict([('recall@10', 0.0107), ('mrr@10', 0.0114), ('ndcg@10', 0.0072), ('hit@10', 0.0352), ('precision@10', 0.0036), ('map@10', 0.0035)])
# 02 Dec 01:31    INFO  test result: OrderedDict([('recall@10', 0.0115), ('mrr@10', 0.0126), ('ndcg@10', 0.0079), ('hit@10', 0.0361), ('precision@10', 0.0039), ('map@10', 0.0039)])

# %% [markdown]
# More Feature

# %%
# user-based MF
# add 'item': item_col in 'load_col'
! python ../bole/run.py --model=MF
# Out:
# 02 Dec 01:46    INFO  ['../bole/run.py']
# 02 Dec 01:46    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = /content/drive/Shareddrives/SI650_Final_Project/RecBole/dataset/ZhihuRec-1M
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 300
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator = ,
# seq_separator =
# USER_ID_FIELD = userID
# ITEM_ID_FIELD = answerID
# RATING_FIELD = is_clicked
# TIME_FIELD = imp_ts
# seq_len = None
# LABEL_FIELD = is_clicked
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['userID', 'answerID', 'imp_ts', 'is_clicked'], 'user': ['userID', 'gender', 'n_followers', 'n_topics_followed', 'n_questions_followed', 'n_answers', 'n_questions', 'n_comments', 'n_thanks_recv', 'n_comments_recv', 'n_likes_recv', 'n_dislikes_recv', 'province']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'val', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# user_embedding_size = 64
# item_embedding_size = 64
# user_hidden_size_list = [64, 64]
# item_hidden_size_list = [64, 64]
# embedding_size = 10
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 02 Dec 01:46    INFO  ZhihuRec-1M
# The number of users: 7975
# Average actions of users: 125.40381239026837
# The number of items: 81564
# Average actions of items: 12.260093424714638
# The number of inters: 999970
# The sparsity of the dataset: 99.84627030580367%
# Remain Fields: ['userID', 'answerID', 'is_clicked', 'imp_ts', 'gender', 'n_followers', 'n_topics_followed', 'n_questions_followed', 'n_answers', 'n_questions', 'n_comments', 'n_thanks_recv', 'n_comments_recv', 'n_likes_recv', 'n_dislikes_recv', 'province']
# 02 Dec 01:46    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 02 Dec 01:46    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}]
# 02 Dec 01:46    INFO  MF(
#   (user_embedding): Embedding(7975, 10)
#   (item_embedding): Embedding(81564, 10)
#   (loss): MSELoss()
#   (bce_loss): BCEWithLogitsLoss()
#   (sigmoid): Sigmoid()
# )
# Trainable parameters: 895390
# 02 Dec 01:46    INFO  FLOPs: 20.0
# Train     0: 100%|████████████████████████████████████████████████| 905/905 [00:13<00:00, 68.35it/s]
# 02 Dec 01:46    INFO  epoch 0 training [time: 13.24s, train loss: 320.9653]
# Evaluate   : 100%|█████████████████████████████████████████████| 7974/7974 [00:17<00:00, 465.16it/s]
# 02 Dec 01:47    INFO  epoch 0 evaluating [time: 17.21s, valid_score: 0.011400]
# 02 Dec 01:47    INFO  valid result:
# recall@10 : 0.0107    mrr@10 : 0.0114    ndcg@10 : 0.0072    hit@10 : 0.0352    precision@10 : 0.0036    map@10 : 0.0035
# 02 Dec 01:47    INFO  Saving current: saved/MF-Dec-02-2022_01-46-38.pth
# Train     1: 100%|████████████████████████████████████████████████| 905/905 [00:12<00:00, 74.69it/s]
# 02 Dec 01:47    INFO  epoch 1 training [time: 12.12s, train loss: 111.6411]
# Evaluate   : 100%|█████████████████████████████████████████████| 7974/7974 [00:16<00:00, 473.39it/s]
# 02 Dec 01:47    INFO  epoch 1 evaluating [time: 16.91s, valid_score: 0.005600]
# 02 Dec 01:47    INFO  valid result:
# recall@10 : 0.0077    mrr@10 : 0.0056    ndcg@10 : 0.0044    hit@10 : 0.0219    precision@10 : 0.0022    map@10 : 0.0021
# Train     2: 100%|████████████████████████████████████████████████| 905/905 [00:12<00:00, 74.83it/s]
# 02 Dec 01:47    INFO  epoch 2 training [time: 12.09s, train loss: 99.3033]
# Evaluate   : 100%|█████████████████████████████████████████████| 7974/7974 [00
 100%|████████████████████████████████████████████████| 905/905 [00:12<00:00, 74.63it/s]
# 02 Dec 01:51    INFO  epoch 10 training [time: 12.13s, train loss: 70.7205]
# Evaluate   : 100%|█████████████████████████████████████████████| 7974/7974 [00:17<00:00, 447.12it/s]
# 02 Dec 01:52    INFO  epoch 10 evaluating [time: 17.90s, valid_score: 0.009500]
# 02 Dec 01:52    INFO  valid result:
# recall@10 : 0.01    mrr@10 : 0.0095    ndcg@10 : 0.0062    hit@10 : 0.0354    precision@10 : 0.0037    map@10 : 0.0027
# Train    11: 100%|████████████████████████████████████████████████| 905/905 [00:12<00:00, 74.91it/s]
# 02 Dec 01:52    INFO  epoch 11 training [time: 12.08s, train loss: 68.2423]
# Evaluate   : 100%|█████████████████████████████████████████████| 7974/7974 [00:17<00:00, 450.15it/s]
# 02 Dec 01:52    INFO  epoch 11 evaluating [time: 17.78s, valid_score: 0.009400]
# 02 Dec 01:52    INFO  valid result:
# recall@10 : 0.0083    mrr@10 : 0.0094    ndcg@10 : 0.0057    hit@10 : 0.0317    precision@10 : 0.0034    map@10 : 0.0025
# 02 Dec 01:52    INFO  Finished training, best eval result in epoch 0
# 02 Dec 01:52    INFO  Loading model structure and parameters from saved/MF-Dec-02-2022_01-46-38.pth
# Evaluate   : 100%|█████████████████████████████████████████████| 7974/7974 [00:17<00:00, 461.54it/s]
# 02 Dec 01:52    INFO  best valid : OrderedDict([('recall@10', 0.0107), ('mrr@10', 0.0114), ('ndcg@10', 0.0072), ('hit@10', 0.0352), ('precision@10', 0.0036), ('map@10', 0.0035)])
# 02 Dec 01:52    INFO  test result: OrderedDict([('recall@10', 0.0115), ('mrr@10', 0.0126), ('ndcg@10', 0.0079), ('hit@10', 0.0361), ('precision@10', 0.0039), ('map@10', 0.0039)])

# %%
# ItemKNN 有些问题
! python ../bole/run.py --model=ItemKNN
# Out:
# 11 Dec 23:34    INFO  ['../bole/run.py', '--model=ItemKNN']
# 11 Dec 23:34    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = /content/drive/Shareddrives/SI650_Final_Project/RecBole/dataset/ZhihuRec-1M
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 300
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator = ,
# seq_separator =
# USER_ID_FIELD = userID
# ITEM_ID_FIELD = answerID
# RATING_FIELD = is_clicked
# TIME_FIELD = imp_ts
# seq_len = None
# LABEL_FIELD = is_clicked
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['userID', 'answerID', 'imp_ts', 'is_clicked'], 'item': ['answerID', 'is_anonymous', 'is_hi_val', 'is_editor_recom', 'has_pic', 'has_vid', 'n_thanks', 'n_likes', 'n_comments', 'n_collections', 'n_dislikes', 'n_reports', 'n_helpless']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'val', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# k = 100
# shrink = 0.0
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.TRADITIONAL
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 11 Dec 23:34    INFO  ZhihuRec-1M
# The number of users: 7975
# Average actions of users: 125.40381239026837
# The number of items: 81564
# Average actions of items: 12.260093424714638
# The number of inters: 999970
# The sparsity of the dataset: 99.84627030580367%
# Remain Fields: ['userID', 'answerID', 'is_clicked', 'imp_ts', 'is_anonymous', 'is_hi_val', 'is_editor_recom', 'has_pic', 'has_vid', 'n_thanks', 'n_likes', 'n_comments', 'n_collections', 'n_dislikes', 'n_reports', 'n_helpless']
# 11 Dec 23:34    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 11 Dec 23:34    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}]
# 11 Dec 23:35    INFO  ItemKNN()
# Trainable parameters: 1
# ^C

# %%
! python ../bole/run.py --model=BPR
# Out:
# 11 Dec 23:29    INFO  ['../bole/run.py', '--model=BPR']
# 11 Dec 23:29    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = /content/drive/Shareddrives/SI650_Final_Project/RecBole/dataset/ZhihuRec-1M
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 300
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator = ,
# seq_separator =
# USER_ID_FIELD = userID
# ITEM_ID_FIELD = answerID
# RATING_FIELD = is_clicked
# TIME_FIELD = imp_ts
# seq_len = None
# LABEL_FIELD = is_clicked
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['userID', 'answerID', 'imp_ts', 'is_clicked'], 'item': ['answerID', 'is_anonymous', 'is_hi_val', 'is_editor_recom', 'has_pic', 'has_vid', 'n_thanks', 'n_likes', 'n_comments', 'n_collections', 'n_dislikes', 'n_reports', 'n_helpless']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'val', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 11 Dec 23:29    INFO  ZhihuRec-1M
# The number of users: 7975
# Average actions of users: 125.40381239026837
# The number of items: 81564
# Average actions of items: 12.260093424714638
# The number of inters: 999970
# The sparsity of the dataset: 99.84627030580367%
# Remain Fields: ['userID', 'answerID', 'is_clicked', 'imp_ts', 'is_anonymous', 'is_hi_val', 'is_editor_recom', 'has_pic', 'has_vid', 'n_thanks', 'n_likes', 'n_comments', 'n_collections', 'n_dislikes', 'n_reports', 'n_helpless']
# 11 Dec 23:29    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 11 Dec 23:29    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}]
# 11 Dec 23:29    INFO  BPR(
#   (user_embedding): Embedding(7975, 64)
#   (item_embedding): Embedding(81564, 64)
#   (loss): BPRLoss()
# )
# Trainable parameters: 5730496
# 11 Dec 23:29    INFO  FLOPs: 128.0
# Train     0: 100%|████████████████████████████████████████████████| 453/453 [00:17<00:00, 25.47it/s]
# 11 Dec 23:29    INFO  epoch 0 training [time: 17.78s, train loss: 267.5844]
# Evaluate   : 100%|█████████████████████████████████████████████| 7974/7974 [00:16<00:00, 489.10it/s]
# 11 Dec 23:30    INFO  epoch 0 evaluating [time: 16.36s, valid_score: 0.012000]
# 11 Dec 23:30    INFO  valid result:
# recall@10 : 0.0127    mrr@10 : 0.012    ndcg@10 : 0.0083    hit@10 : 0.0386    precision@10 : 0.0041    map@10 : 0.0042
# 11 Dec 23:30    INFO  Saving current: saved/BPR-Dec-11-2022_23-29-29.pth
# Train     1: 100%|████████████████████████████████████████████████| 453/453 [00:16<00:00, 27.77it/s]
# 11 Dec 23:30    INFO  epoch 1 training [time: 16.31s, train loss: 115.5510]
# Evaluate   :  10%|████▍                                         | 775/7974 [00:01<00:13, 533.77it/s]
# Traceback (most recent call last):
#   File "../bole/run.py", line 46, in <module>
#     run_recbole(dataset='ZhihuRec-1M', config_dict=parameter_dict)
#   File "/content/drive/Shareddrives/SI650_Final_Project/RecBole/recbole/quick_start/quick_start.py", line 88, in run_recbole
#     best_valid_score, best_valid_result = trainer.fit(
#   File "/content/drive/Shareddrives/SI650_Final_Project/RecBole/recbole/trainer/trainer.py", line 462, in fit
#     valid_score, valid_result = self._valid_epoch(
#   File "/content/drive/Shareddrives/SI650_Final_Project/RecBole/recbole/trainer/trainer.py", line 281, in _valid_epoch
#     valid_result = self.evaluate(
#   File "/usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/drive/Shareddrives/SI650_Final_Project/RecBole/recbole/trainer/trainer.py", line 613, in evaluate
#     interaction, scores, positive_u, positive_i = eval_func(batched_data)
#   File "/content/drive/Shareddrives/SI650_Final_Project/RecBole/recbole/trainer/trainer.py", line 522, in _full_sort_batch_eval
#     scores = self.model.full_sort_predict(interaction.to(self.device))
#   File "/content/drive/Shareddrives/SI650_Final_Project/RecBole/recbole/model/general_recommender/bpr.py", line 95, in full_sort_predict
#     score = torch.matmul(user_e, all_item_e.transpose(0, 1))
# KeyboardInterrupt
# ^C

# %%
! python ../bole/run.py --model=LightGCN
# Out:
# 11 Dec 23:30    INFO  ['../bole/run.py', '--model=LightGCN']
# 11 Dec 23:30    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = /content/drive/Shareddrives/SI650_Final_Project/RecBole/dataset/ZhihuRec-1M
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 300
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator = ,
# seq_separator =
# USER_ID_FIELD = userID
# ITEM_ID_FIELD = answerID
# RATING_FIELD = is_clicked
# TIME_FIELD = imp_ts
# seq_len = None
# LABEL_FIELD = is_clicked
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['userID', 'answerID', 'imp_ts', 'is_clicked'], 'item': ['answerID', 'is_anonymous', 'is_hi_val', 'is_editor_recom', 'has_pic', 'has_vid', 'n_thanks', 'n_likes', 'n_comments', 'n_collections', 'n_dislikes', 'n_reports', 'n_helpless']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'val', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# n_layers = 2
# reg_weight = 1e-05
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 11 Dec 23:30    INFO  ZhihuRec-1M
# The number of users: 7975
# Average actions of users: 125.40381239026837
# The number of items: 81564
# Average actions of items: 12.260093424714638
# The number of inters: 999970
# The sparsity of the dataset: 99.84627030580367%
# Remain Fields: ['userID', 'answerID', 'is_clicked', 'imp_ts', 'is_anonymous', 'is_hi_val', 'is_editor_recom', 'has_pic', 'has_vid', 'n_thanks', 'n_likes', 'n_comments', 'n_collections', 'n_dislikes', 'n_reports', 'n_helpless']
# 11 Dec 23:30    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 11 Dec 23:30    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}]
# 11 Dec 23:30    INFO  LightGCN(
#   (user_embedding): Embedding(7975, 64)
#   (item_embedding): Embedding(81564, 64)
#   (mf_loss): BPRLoss()
#   (reg_loss): EmbLoss()
# )
# Trainable parameters: 5730496
# 11 Dec 23:30    INFO  FLOPs: 0.0
# Train     0: 100%|████████████████████████████████████████████████| 453/453 [02:35<00:00,  2.91it/s]
# 11 Dec 23:33    INFO  epoch 0 training [time: 155.78s, train loss: 166.0624]
# Evaluate   :  11%|█████▏                                        | 894/7974 [00:01<00:14, 476.19it/s]
# Traceback (most recent call last):
#   File "../bole/run.py", line 46, in <module>
#     run_recbole(dataset='ZhihuRec-1M', config_dict=parameter_dict)
#   File "/content/drive/Shareddrives/SI650_Final_Project/RecBole/recbole/quick_start/quick_start.py", line 88, in run_recbole
#     best_valid_score, best_valid_result = trainer.fit(
#   File "/content/drive/Shareddrives/SI650_Final_Project/RecBole/recbole/trainer/trainer.py", line 462, in fit
#     valid_score, valid_result = self._valid_epoch(
#   File "/content/drive/Shareddrives/SI650_Final_Project/RecBole/recbole/trainer/trainer.py", line 281, in _valid_epoch
#     valid_result = self.evaluate(
#   File "/usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/drive/Shareddrives/SI650_Final_Project/RecBole/recbole/trainer/trainer.py", line 613, in evaluate
#     interaction, scores, positive_u, positive_i = eval_func(batched_data)
#   File "/content/drive/Shareddrives/SI650_Final_Project/RecBole/recbole/trainer/trainer.py", line 522, in _full_sort_batch_eval
#     scores = self.model.full_sort_predict(interaction.to(self.device))
#   File "/content/drive/Shareddrives/SI650_Final_Project/RecBole/recbole/model/general_recommender/lightgcn.py", line 207, in full_sort_predict
#     scores = torch.matmul(u_embeddings, self.restore_item_e.transpose(0, 1))
# KeyboardInterrupt
# ^C

# %%
! python ../bole/run.py --model=ENMF
# Out:
# 11 Dec 23:33    INFO  ['../bole/run.py', '--model=ENMF']
# 11 Dec 23:33    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = /content/drive/Shareddrives/SI650_Final_Project/RecBole/dataset/ZhihuRec-1M
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 300
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision', 'MAP']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator = ,
# seq_separator =
# USER_ID_FIELD = userID
# ITEM_ID_FIELD = answerID
# RATING_FIELD = is_clicked
# TIME_FIELD = imp_ts
# seq_len = None
# LABEL_FIELD = is_clicked
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['userID', 'answerID', 'imp_ts', 'is_clicked'], 'item': ['answerID', 'is_anonymous', 'is_hi_val', 'is_editor_recom', 'has_pic', 'has_vid', 'n_thanks', 'n_likes', 'n_comments', 'n_collections', 'n_dislikes', 'n_reports', 'n_helpless']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'val', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# dropout_prob = 0.7
# reg_weight = 0.0
# negative_weight = 0.5
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 11 Dec 23:33    INFO  ZhihuRec-1M
# The number of users: 7975
# Average actions of users: 125.40381239026837
# The number of items: 81564
# Average actions of items: 12.260093424714638
# The number of inters: 999970
# The sparsity of the dataset: 99.84627030580367%
# Remain Fields: ['userID', 'answerID', 'is_clicked', 'imp_ts', 'is_anonymous', 'is_hi_val', 'is_editor_recom', 'has_pic', 'has_vid', 'n_thanks', 'n_likes', 'n_comments', 'n_collections', 'n_dislikes', 'n_reports', 'n_helpless']
# 11 Dec 23:33    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 11 Dec 23:33    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'group_by': 'user', 'order': 'RO', 'mode': 'full'}]
# 11 Dec 23:33    INFO  ENMF(
#   (user_embedding): Embedding(7975, 64, padding_idx=0)
#   (item_embedding): Embedding(81564, 64, padding_idx=0)
#   (H_i): Linear(in_features=64, out_features=1, bias=False)
#   (dropout): Dropout(p=0.7, inplace=False)
# )
# Trainable parameters: 5730560
# 11 Dec 23:33    INFO  FLOPs: 192.0
# Train     0:   0%|                                                            | 0/4 [00:00<?, ?it/s]tcmalloc: large alloc 1336344576 bytes == 0x285f8000 @  0x7f03f0b40b6b 0x7f03f0b60379 0x7f036563c935 0x7f036561a093 0x7f03926e753f 0x7f03926e8360 0x7f03926e83b4 0x7f03926e84ff 0x7f03937e014b 0x7f039382f220 0x7f0392b7c590 0x7f0392b66696 0x7f03937d80a9 0x7f03937d80f0 0x7f03935be0be 0x7f0394dd6a7c 0x7f0394dd7483 0x7f0393610771 0x7f03bb27a3b0 0x5d80be 0x5d8d8c 0x561f80 0x4fd2db 0x4990ca 0x4fd8b5 0x49abe4 0x4fd8b5 0x49abe4 0x55cd91 0x5d8941 0x49abe4
# Train     0:  25%|█████████████                                       | 1/4 [00:01<00:03,  1.03s/it]tcmalloc: large alloc 1336344576 bytes == 0x2f508000 @  0x7f03f0b40b6b 0x7f03f0b60379 0x7f036563c935 0x7f036561a093 0x7f03926e753f 0x7f03926e8360 0x7f03926e83b4 0x7f03926e84ff 0x7f03937e014b 0x7f039382f220 0x7f0392b7c590 0x7f0392b66696 0x7f03937d80a9 0x7f03937d80f0 0x7f03935be0be 0x7f0394dd6a7c 0x7f0394dd7483 0x7f0393610771 0x7f03bb27a3b0 0x5d80be 0x5d8d8c 0x561f80 0x4fd2db 0x4990ca 0x4fd8b5 0x49abe4 0x4fd8b5 0x49abe4 0x55cd91 0x5d8941 0x49abe4
# Train     0: 100%|████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.21it/s]
# 11 Dec 23:33    INFO  epoch 0 training [time: 3.31s, train loss: 3.8202]
# Evaluate   :  12%|█████▌                                        | 974/7974 [00:04<00:34, 202.17it/s]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/drive/Shareddrives/SI650_Final_Project/RecBole/recbole/trainer/trainer.py", line 618, in evaluate
#     self.eval_collector.eval_batch_collect(
#   File "/content/drive/Shareddrives/SI650_Final_Project/RecBole/recbole/evaluator/collector.py", line 166, in eval_batch_collect
#     pos_len_list = pos_matrix.sum(dim=1, keepdim=True)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../bole/run.py", line 46, in <module>
#     run_recbole(dataset='ZhihuRec-1M', config_dict=parameter_dict)
#   File "/content/drive/Shareddrives/SI650_Final_Project/RecBole/recbole/quick_start/quick_start.py", line 88, in run_recbole
#     best_valid_score, best_valid_result = trainer.fit(
#   File "/content/drive/Shareddrives/SI650_Final_Project/RecBole/recbole/trainer/trainer.py", line 462, in fit
#     valid_score, valid_result = self._valid_epoch(
#   File "/content/drive/Shareddrives/SI650_Final_Project/RecBole/recbole/trainer/trainer.py", line 281, in _valid_epoch
#     valid_result = self.evaluate(
#   File "/usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py", line 136, in __exit__
#     torch.set_grad_enabled(self.prev)
#   File "/usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py", line 229, in __init__
#     torch._C._set_grad_enabled(mode)
# KeyboardInterrupt
# ^C
